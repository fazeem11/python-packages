# %%
import pandas as pd
df=pd.read_csv('gender_classification_v7.csv')
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
x=df.drop(['gender'] ,axis=1)
y=df['gender']
x
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long
# 0             1                          1
# 1             1                          0
# 2             1                          1
# 3             1                          1
# 4             0                          0
# ...         ...                        ...
# 4996          0                          0
# 4997          0                          0
# 4998          0                          0
# 4999          0                          0
# 5000          1                          1
#
# [5001 rows x 7 columns]

# %%
y
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4       Female
#          ...
# 4996    Female
# 4997    Female
# 4998    Female
# 4999    Female
# 5000      Male
# Name: gender, Length: 5001, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
X_train.shape
# Out:
# (3500, 7)

# %%
X_test.shape
# Out:
# (1501, 7)

# %%
y_train.shape
# Out:
# (3500,)

# %%
y_test.shape
# Out:
# (1501,)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier()
clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=clf.predict(X_test)
y_pred
# Out:
# array(['Male', 'Female', 'Female', ..., 'Female', 'Male', 'Female'],
#       dtype=object)

# %%
y_pred.shape
# Out:
# (1501,)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[748,  21],
#        [ 29, 703]], dtype=int64)

# %%
new_data=[[1,11.8,6.1,1,0,1,1]]
y_pred=clf.predict(new_data)
y_pred
# Out:
# C:\Users\muham\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Male'], dtype=object)

# %%
import pandas as pd
df=pd.read_csv('adult.csv')
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
x=df.drop(['income'] ,axis=1)
y=df['income']
x
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country
# 0                 0             0              40  United-States
# 1                 0             0              50  United-States
# 2                 0             0              40  United-States
# 3              7688             0              40  United-States
# 4                 0             0              30  United-States
# ...             ...           ...             ...            ...
# 48837             0             0              38  United-States
# 48838             0             0              40  United-States
# 48839             0             0              40  United-States
# 48840             0             0              20  United-States
# 48841         15024             0              40  United-States
#
# [48842 rows x 14 columns]

# %%
X_encoded = pd.get_dummies(x)
X_encoded
# Out:
#        age  fnlwgt  educational-num  capital-gain  capital-loss  \
# 0       25  226802                7             0             0
# 1       38   89814                9             0             0
# 2       28  336951               12             0             0
# 3       44  160323               10          7688             0
# 4       18  103497               10             0             0
# ...    ...     ...              ...           ...           ...
# 48837   27  257302               12             0             0
# 48838   40  154374                9             0             0
# 48839   58  151910                9             0             0
# 48840   22  201490                9             0             0
# 48841   52  287927                9         15024             0
#
#        hours-per-week  workclass_?  workclass_Federal-gov  \
# 0                  40        False                  False
# 1                  50        False                  False
# 2                  40        False                  False
# 3                  40        False                  False
# 4                  30         True                  False
# ...               ...          ...                    ...
# 48837              38        False                  False
# 48838              40        False                  False
# 48839              40        False                  False
# 48840              20        False                  False
# 48841              40        False                  False
#
#        workclass_Local-gov  workclass_Never-worked  ...  \
# 0                    False                   False  ...
# 1                    False                   False  ...
# 2                     True                   False  ...
# 3                    False                   False  ...
# 4                    False                   False  ...
# ...                    ...                     ...  ...
# 48837                False                   False  ...
# 48838                False                   False  ...
# 48839                False                   False  ...
# 48840                False                   False  ...
# 48841                False                   False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48837                    False                       False
# 48838                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48837                    False                 False                  False
# 48838                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48837                    False                           False
# 48838                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                              True                   False
# ...                             ...                     ...
# 48837                          True                   False
# 48838                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48837                      False
# 48838                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [48842 rows x 108 columns]

# %%
# Split your data into training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 48842, dtype: object

# %%
X_test.shape
# Out:
# (9769, 108)

# %%
y_train.shape
# Out:
# (39073,)

# %%
y_test.shape
# Out:
# (9769,)

# %%
X_train = pd.get_dummies(X_train)

# Then fit the model
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier()
clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
X_train
# Out:
#        age  fnlwgt  educational-num  capital-gain  capital-loss  \
# 37193   42  145175               10             0             0
# 31093   52  175029                6             0             0
# 33814   34  172664                9             0             0
# 14500   28  125791                9             0             0
# 23399   46   28419               11             0             0
# ...    ...     ...              ...           ...           ...
# 11284   36  635913                9             0             0
# 44732   34  107624               10             0             0
# 38158   28  250135               10             0             0
# 860     46   96652               11             0             0
# 15795   59  176118               14             0             0
#
#        hours-per-week  workclass_?  workclass_Federal-gov  \
# 37193              40        False                  False
# 31093              35        False                  False
# 33814              40        False                  False
# 14500              40        False                  False
# 23399              50        False                  False
# ...               ...          ...                    ...
# 11284              40        False                  False
# 44732              50        False                  False
# 38158              40        False                  False
# 860                40        False                  False
# 15795               7        False                  False
#
#        workclass_Local-gov  workclass_Never-worked  ...  \
# 37193                False                   False  ...
# 31093                False                   False  ...
# 33814                 True                   False  ...
# 14500                False                   False  ...
# 23399                False                   False  ...
# ...                    ...                     ...  ...
# 11284                False                   False  ...
# 44732                False                   False  ...
# 38158                False                   False  ...
# 860                  False                   False  ...
# 15795                False                   False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 37193                    False                       False
# 31093                    False                       False
# 33814                    False                       False
# 14500                    False                       False
# 23399                    False                       False
# ...                        ...                         ...
# 11284                    False                       False
# 44732                    False                       False
# 38158                    False                       False
# 860                      False                       False
# 15795                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 37193                    False                 False                  False
# 31093                    False                 False                  False
# 33814                    False                 False                  False
# 14500                    False                 False                  False
# 23399                    False                 False                  False
# ...                        ...                   ...                    ...
# 11284                    False                 False                  False
# 44732                    False                 False                  False
# 38158                    False                 False                  False
# 860                      False                 False                  False
# 15795                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 37193                    False                           False
# 31093                    False                           False
# 33814                    False                           False
# 14500                    False                           False
# 23399                    False                           False
# ...                        ...                             ...
# 11284                    False                           False
# 44732                    False                           False
# 38158                    False                           False
# 860                      False                           False
# 15795                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 37193                          True                   False
# 31093                          True                   False
# 33814                          True                   False
# 14500                          True                   False
# 23399                          True                   False
# ...                             ...                     ...
# 11284                          True                   False
# 44732                          True                   False
# 38158                          True                   False
# 860                            True                   False
# 15795                          True                   False
#
#        native-country_Yugoslavia
# 37193                      False
# 31093                      False
# 33814                      False
# 14500                      False
# 23399                      False
# ...                          ...
# 11284                      False
# 44732                      False
# 38158                      False
# 860                        False
# 15795                      False
#
# [39073 rows x 108 columns]

# %%
y_pred=clf.predict(X_test)
y_pred
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '>50K'],
#       dtype=object)

# %%
y_pred.shape
# Out:
# (9769,)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[6874,  605],
#        [1510,  780]], dtype=int64)
