# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('adult.csv')  # Replace with your actual file path
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# List of columns to drop
columns_to_drop = ['workclass', 'marital-status', 'occupation', 
                   'relationship', 'race', 'gender', 'native-country']

# %%
df = df.drop(columns=columns_to_drop, axis=1)

# %%
X = df.drop('income', axis=1)  # Replace 'income' with your actual target column name
y = df['income']  # Target variable

# %%
X
# Out:
#        age  fnlwgt     education  educational-num  capital-gain  capital-loss  \
# 0       25  226802          11th                7             0             0
# 1       38   89814       HS-grad                9             0             0
# 2       28  336951    Assoc-acdm               12             0             0
# 3       44  160323  Some-college               10          7688             0
# 4       18  103497  Some-college               10             0             0
# ...    ...     ...           ...              ...           ...           ...
# 48837   27  257302    Assoc-acdm               12             0             0
# 48838   40  154374       HS-grad                9             0             0
# 48839   58  151910       HS-grad                9             0             0
# 48840   22  201490       HS-grad                9             0             0
# 48841   52  287927       HS-grad                9         15024             0
#
#        hours-per-week
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 48842, dtype: object

# %%
# Apply one-hot encoding to categorical columns
X_encoded = pd.get_dummies(X, drop_first=True)

# %%
X_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     48842 non-null  int64
#  1   fnlwgt                  48842 non-null  int64
#  2   educational-num         48842 non-null  int64
#  3   capital-gain            48842 non-null  int64
#  4   capital-loss            48842 non-null  int64
#  5   hours-per-week          48842 non-null  int64
#  6   education_11th          48842 non-null  bool
#  7   education_12th          48842 non-null  bool
#  8   education_1st-4th       48842 non-null  bool
#  9   education_5th-6th       48842 non-null  bool
#  10  education_7th-8th       48842 non-null  bool
#  11  education_9th           48842 non-null  bool
#  12  education_Assoc-acdm    48842 non-null  bool
#  13  education_Assoc-voc     48842 non-null  bool
# ...

# %%
X_encoded.columns
# Out:
# Index(['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'education_11th', 'education_12th',
#        'education_1st-4th', 'education_5th-6th', 'education_7th-8th',
#        'education_9th', 'education_Assoc-acdm', 'education_Assoc-voc',
#        'education_Bachelors', 'education_Doctorate', 'education_HS-grad',
#        'education_Masters', 'education_Preschool', 'education_Prof-school',
#        'education_Some-college'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Fit to the training data
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can choose a different number of neighbors

# Fit the model
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score

# Predict on the test set
y_pred = knn.predict(X_test_scaled)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.81

# %%
# Prepare new data for prediction
new_data_dict = {
    'age': [26],
    'fnlwgt': [160325],
    'educational-num': [10],
    'capital-gain': [0],
    'capital-loss': [0],
    'hours-per-week': [40],
    'education_11th': [1],
    'education_12th': [0],
    'education_1st-4th': [0],
    'education_5th-6th': [0],
    'education_7th-8th': [0],
    'education_Assoc-acdm': [0],
    'education_HS-grad': [0],
    'education_Some-college': [0],
    # Add other features as necessary
}

# Create DataFrame from new data dictionary
new_data = pd.DataFrame(new_data_dict)

# Reindex new data to match the training set columns
new_data = new_data.reindex(columns=X_encoded.columns, fill_value=0)

# Make prediction on new data
y_new_pred = knn.predict(new_data)
print(f'Prediction for the new data: {y_new_pred[0]}')
# Out:
# Prediction for the new data: <=50K

# %%
from sklearn.metrics import accuracy_score

# Assuming you have X_train, X_test, y_train, and y_test defined, and your model is trained
# Make predictions on the test set
y_pred = knn.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f'Accuracy: {accuracy:.2f}')  # Prints accuracy as a decimal (e.g., 0.85)
# Out:
# Accuracy: 0.78
