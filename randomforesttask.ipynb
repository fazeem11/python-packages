# %%
import pandas as pd
df= pd.read_csv('combats.csv')
df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   First_pokemon   50000 non-null  int64
#  1   Second_pokemon  50000 non-null  int64
#  2   Winner          50000 non-null  int64
# dtypes: int64(3)
# memory usage: 1.1 MB

# %%
df.isnull()
# Out:
#        First_pokemon  Second_pokemon  Winner
# 0              False           False   False
# 1              False           False   False
# 2              False           False   False
# 3              False           False   False
# 4              False           False   False
# ...              ...             ...     ...
# 49995          False           False   False
# 49996          False           False   False
# 49997          False           False   False
# 49998          False           False   False
# 49999          False           False   False
#
# [50000 rows x 3 columns]

# %%
x = df[['First_pokemon', 'Second_pokemon']]
x
# Out:
#        First_pokemon  Second_pokemon
# 0                266             298
# 1                702             701
# 2                191             668
# 3                237             683
# 4                151             231
# ...              ...             ...
# 49995            707             126
# 49996            589             664
# 49997            303             368
# 49998            109              89
# 49999              9              73
#
# [50000 rows x 2 columns]

# %%
y=df['Winner']

# %%
y.head()
# Out:
# 0    298
# 1    701
# 2    668
# 3    683
# 4    151
# Name: Winner, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
X_train
# Out:
#        First_pokemon  Second_pokemon
# 48824            773             281
# 2704             450             119
# 25631            169             513
# 7285             113             291
# 27346             35             707
# ...              ...             ...
# 16304            374             737
# 79               125             418
# 12119            673             143
# 14147            244             409
# 38408            367             587
#
# [35000 rows x 2 columns]

# %%
X_test
# Out:
#        First_pokemon  Second_pokemon
# 4253             487              96
# 30076            153             668
# 48047            421             230
# 1666             703             619
# 30740             68              47
# ...              ...             ...
# 24718             81             319
# 28544            611             452
# 37929            588             744
# 34814            599              36
# 25776            762             797
#
# [15000 rows x 2 columns]

# %%
y_train
# Out:
# 48824    773
# 2704     119
# 25631    513
# 7285     291
# 27346    707
#         ...
# 16304    737
# 79       418
# 12119    673
# 14147    409
# 38408    367
# Name: Winner, Length: 35000, dtype: int64

# %%
y_test
# Out:
# 4253      96
# 30076    153
# 48047    421
# 1666     703
# 30740     68
#         ...
# 24718    319
# 28544    611
# 37929    588
# 34814     36
# 25776    797
# Name: Winner, Length: 15000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sl=StandardScaler()
X_train=sl.fit_transform(X_train)
X_test=sl.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 1.62338294, -0.52695634],
#        [ 0.21736912, -1.22898881],
#        [-1.00581938,  0.47842349],
#        ...,
#        [ 1.18808454, -1.124984  ],
#        [-0.67934558,  0.02773598],
#        [-0.14392855,  0.79910498]])

# %%
X_test
# Out:
# array([[ 0.37315387, -1.35003249],
#        [-1.08458074,  1.15338091],
#        [ 0.08509853, -0.76356851],
#        ...,
#        [ 0.81396584,  1.48600227],
#        [ 0.86197506, -1.6126283 ],
#        [ 1.57338446,  1.7179619 ]])

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
y_pred
# Out:
# array([ 93, 151, 420, ..., 746,  30, 799], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 3,  0,  0, ...,  0,  0,  0],
#        [ 3,  2,  0, ...,  0,  0,  0],
#        [10,  2,  0, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ...,  2,  0,  7],
#        [ 0,  0,  0, ...,  0,  9,  7],
#        [ 0,  0,  0, ...,  0,  0, 11]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.07233333333333333

# %%
new_data=[[433,456]]
y_pred=clf.predict(new_data)
y_pred
# Out:
# array([800], dtype=int64)
